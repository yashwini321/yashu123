# %% [markdown]
# <a href="https://colab.research.google.com/github/yashwini321/yashu123/blob/main/ex4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
max=lambda a,b:a if (a>b) else b
print(max(4,5))
x=lambda a:a+1
print(x(5))
x=lambda a,b,c:a+b+c
print(x(5,6,2))
# Out:
# 5
# 6
# 13

# %%
def add4(x):
  return x+4
list1=[4,6,7,8,9]
list2=list(map(add4,list1))
print(list2)
# Out:
# [8, 10, 11, 12, 13]
