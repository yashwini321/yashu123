# %% [markdown]
# <a href="https://colab.research.google.com/github/yashwini321/yashu123/blob/main/exp12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import  numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegreesion
from sklearn import linear_model from sklearn.metrics
import mean_squared.error,mean_abssolute_error
df=pd.read_csv('')
print(df)
print(df.info())
df.isnull().sum()
print(df.head())
plt.scatter(df.rm,df.)
